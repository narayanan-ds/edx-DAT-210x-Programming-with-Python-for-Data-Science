# %%
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D #Package to use for 3D plots
plt.style.use('ggplot')
# %matplotlib notebook

# %%
sd = pd.read_csv('students.data')
sd.head()
# Out:
#    id  sex  age  address  famsize  Pstatus  Medu  Fedu  traveltime  studytime  \
# 0   0    1   18        0        1        0     4     4           2          2
# 1   1    1   17        0        1        1     1     1           1          2
# 2   2    1   15        0        0        1     1     1           1          2
# 3   3    1   15        0        1        1     4     2           1          3
# 4   4    1   16        0        1        1     3     3           1          2
#
#   ...  famrel  freetime  goout  Dalc  Walc  health  absences  G1  G2  G3
# 0 ...       4         3      4     1     1       3         4   0  11  11
# 1 ...       5         3      3     1     1       3         2   9  11  11
# 2 ...       4         3      2     2     3       3         6  12  13  12
# 3 ...       3         2      2     1     1       5         0  14  14  14
# 4 ...       4         3      2     1     2       5         0  11  13  13
#
# [5 rows x 29 columns]

# %%
series = sd.G3
df = sd[['G3','G2','G1']]

# %%
series.plot.hist(alpha=.5)

# %%
df.plot.hist(alpha=.5)

# %%
sd.plot.scatter(x='G2',y='G1',title="Sample plot")

# %% [markdown]
# 3D Plots

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d') # not using the df name directly but as a subplot inside the fig. 
ax.set_xlabel('First Grade')
ax.set_ylabel('Final Grade')
ax.set_zlabel('Daily Alcohol')
	
ax.scatter(sd.G1, sd.G3, sd['Dalc'], c='r', marker='o')#add df column names here
#use matplotlib.inline to avoid this
# Out:
# <img src="data:image/png;base64,..." width="640">
