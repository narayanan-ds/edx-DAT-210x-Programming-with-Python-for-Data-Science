# %% [markdown]
# # DAT210x - Programming with Python for DS

# %% [markdown]
# ## Module3 - Lab3

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
#Package to use for 3D plots
from mpl_toolkits.mplot3d import Axes3D 
#for interactive features
# %matplotlib notebook

# %%
# Look pretty...

# matplotlib.style.use('ggplot')
plt.style.use('ggplot')

# %% [markdown]
# Load up the wheat seeds dataset into a dataframe. We've stored a copy in the Datasets directory.

# %%
df=pd.read_csv('wheat.data')

# %% [markdown]
# Create a new 3D subplot using figure `fig`, which we've defined for you below. Use that subplot to draw a 3D scatter plot using the `area`, `perimeter`, and `asymmetry` features. Be sure so use the optional display parameter `c='red'`, and also label your axes:

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d') # not using the df name directly but as a subplot inside the fig. 
ax.set_xlabel('Area')
ax.set_ylabel('Perimeter')
ax.set_zlabel('Asymmetry')
	
ax.scatter(df.area,df.perimeter,df.asymmetry, c='red', marker='o')#add df column names here
 #use matplotlib.inline to avoid this
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# Create another 3D subplot using fig. Then use the subplot to graph a 3D scatter plot of the `width`, `groove`, and `length` features. Be sure so use the optional display parameter `c='green'`, and be sure to label your axes:

# %%
fig2 = plt.figure()
ax2 = fig2.add_subplot(111, projection='3d') # not using the df name directly but as a subplot inside the fig. 
ax2.set_xlabel('Width')
ax2.set_ylabel('Groove')
ax2.set_zlabel('Length')
	
ax2.scatter(df.width,df.groove,df.length, c='green', marker='*')#add df column names here
 #use matplotlib.inline to avoid this
# Out:
# <img src="data:image/png;base64,..." width="640">
