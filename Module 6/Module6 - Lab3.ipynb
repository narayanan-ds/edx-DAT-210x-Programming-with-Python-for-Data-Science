# %% [markdown]
# # DAT210x - Programming with Python for DS

# %% [markdown]
# ## Module6- Lab3

# %% [markdown]
# This code is intentionally missing! Read the directions on the course lab page!

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import svm
import sklearn.preprocessing as sp

# %%
x=pd.read_csv('parkinsons.data')
x=x.drop(labels=['name'],axis=1)

# %%
print(x.dtypes)
print("\n")
print(x.shape)
print("\n")
print(x.describe())
# Out:
# MDVP:Fo(Hz)         float64
# MDVP:Fhi(Hz)        float64
# MDVP:Flo(Hz)        float64
# MDVP:Jitter(%)      float64
# MDVP:Jitter(Abs)    float64
# MDVP:RAP            float64
# MDVP:PPQ            float64
# Jitter:DDP          float64
# MDVP:Shimmer        float64
# MDVP:Shimmer(dB)    float64
# Shimmer:APQ3        float64
# Shimmer:APQ5        float64
# MDVP:APQ            float64
# Shimmer:DDA         float64
# NHR                 float64
# HNR                 float64
# status                int64
# RPDE                float64
# DFA                 float64
# spread1             float64
# spread2             float64
# D2                  float64
# PPE                 float64
# dtype: object
#
#
# (195, 23)
#
#
#        MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# count   195.000000    195.000000    195.000000      195.000000
# mean    154.228641    197.104918    116.324631        0.006220
# std      41.390065     91.491548     43.521413        0.004848
# ...

# %%
x=x.dropna(axis=0)
x.shape
# Out:
# (195, 23)

# %%
y=x[['status']].copy()
x=x.drop(labels=['status'],axis=1)
x.dtypes
# Out:
# MDVP:Fo(Hz)         float64
# MDVP:Fhi(Hz)        float64
# MDVP:Flo(Hz)        float64
# MDVP:Jitter(%)      float64
# MDVP:Jitter(Abs)    float64
# MDVP:RAP            float64
# MDVP:PPQ            float64
# Jitter:DDP          float64
# MDVP:Shimmer        float64
# MDVP:Shimmer(dB)    float64
# Shimmer:APQ3        float64
# Shimmer:APQ5        float64
# MDVP:APQ            float64
# Shimmer:DDA         float64
# NHR                 float64
# HNR                 float64
# RPDE                float64
# DFA                 float64
# spread1             float64
# spread2             float64
# D2                  float64
# PPE                 float64
# dtype: object

# %%
y_train=np.array(y_train).ravel()
y_test=np.array(y_test).ravel()

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(x,y,test_size=.3,random_state=7)

# %%
from sklearn.svm import SVC
model = SVC()
a=model.fit(X_train,y_train)
score=a.score(X_test,y_test)
score

# %%
c=np.linspace(0.05, 2.0, num=40,dtype=float)
print(c)
print("\n")
g=np.linspace(.001, .1, num=100,dtype=float)
print(g)
# Out:
# [0.05 0.1  0.15 0.2  0.25 0.3  0.35 0.4  0.45 0.5  0.55 0.6  0.65 0.7
#  0.75 0.8  0.85 0.9  0.95 1.   1.05 1.1  1.15 1.2  1.25 1.3  1.35 1.4
#  1.45 1.5  1.55 1.6  1.65 1.7  1.75 1.8  1.85 1.9  1.95 2.  ]
#
#
# [0.001 0.002 0.003 0.004 0.005 0.006 0.007 0.008 0.009 0.01  0.011 0.012
#  0.013 0.014 0.015 0.016 0.017 0.018 0.019 0.02  0.021 0.022 0.023 0.024
#  0.025 0.026 0.027 0.028 0.029 0.03  0.031 0.032 0.033 0.034 0.035 0.036
#  0.037 0.038 0.039 0.04  0.041 0.042 0.043 0.044 0.045 0.046 0.047 0.048
#  0.049 0.05  0.051 0.052 0.053 0.054 0.055 0.056 0.057 0.058 0.059 0.06
#  0.061 0.062 0.063 0.064 0.065 0.066 0.067 0.068 0.069 0.07  0.071 0.072
#  0.073 0.074 0.075 0.076 0.077 0.078 0.079 0.08  0.081 0.082 0.083 0.084
#  0.085 0.086 0.087 0.088 0.089 0.09  0.091 0.092 0.093 0.094 0.095 0.096
#  0.097 0.098 0.099 0.1  ]

# %%
scores=[]
c_=[]
g_=[]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(x,y,test_size=.3,random_state=7)
y_train=np.array(y_train).ravel()
y_test=np.array(y_test).ravel()

# %%
#T = sp.StandardScaler()
T = sp.MinMaxScaler()
#T = sp.MaxAbsScaler()
#T =sp.Normalizer()
#T =sp.RobustScaler()
#T=sp.KernelCenterer()

# %%
X_train=T.fit_transform(X_train)
X_test=T.transform(X_test)

# %%
X_train.shape
# Out:
# (136, 22)

# %%
from sklearn import manifold
iso = manifold.Isomap(n_neighbors=2, n_components=6)
X_train=iso.fit_transform(X_train)
X_test=iso.transform(X_test)
print(X_train.shape)
# Out:
# (136, 6)

# %% [markdown]
# from sklearn.decomposition import PCA
# pca = PCA(n_components=10, svd_solver='full')
# X_train=pca.fit_transform(X_train)
# X_test=pca.transform(X_test)
# print(X_train.shape)

# %%
for i in c:
    for j in g:
        model = SVC(C=i,gamma=j)
        a=model.fit(X_train,y_train)
        score=a.score(X_test,y_test)
        scores.append(score)
        c_.append(i)
        g_.append(j)

# %%
Scoredkc=pd.DataFrame(columns=['Score','C','Gamma'])
Scoredkc['Score']=scores
Scoredkc['C']=c_
Scoredkc['Gamma']=g_
Scoredkc.sort_values(by='Score',ascending=False)
# Out:
#           Score     C  Gamma
# 35858  0.932203  1.95  0.059
# 35283  0.932203  1.65  0.084
# 35853  0.932203  1.95  0.054
# 35854  0.932203  1.95  0.055
# 34783  0.932203  1.40  0.084
# 34784  0.932203  1.40  0.085
# 34785  0.932203  1.40  0.086
# 34786  0.932203  1.40  0.087
# 34787  0.932203  1.40  0.088
# 34788  0.932203  1.40  0.089
# 34789  0.932203  1.40  0.090
# 35385  0.932203  1.70  0.086
# 35859  0.932203  1.95  0.060
# 35860  0.932203  1.95  0.061
# 35861  0.932203  1.95  0.062
# 34790  0.932203  1.40  0.091
# 34791  0.932203  1.40  0.092
# 35862  0.932203  1.95  0.063
# 35863  0.932203  1.95  0.064
# 34792  0.932203  1.40  0.093
# 35864  0.932203  1.95  0.065
# 35780  0.932203  1.90  0.081
# 35779  0.932203  1.90  0.080
# 35778  0.932203  1.90  0.079
# 35767  0.932203  1.90  0.068
# 35755  0.932203  1.90  0.056
# 35760  0.932203  1.90  0.061
# 35761  0.932203  1.90  0.062
# 35762  0.932203  1.90  0.063
# 35763  0.932203  1.90  0.064
# ...         ...   ...    ...
# ...
